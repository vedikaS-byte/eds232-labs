# %% [markdown]
# # Machine Learning Workshop 8:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Read in data
shark = pd.read_csv("/Users/vedikashirtekar/MEDS/EDS-232/eds232-labs/data/GSAF5.xlsx - Sheet1-GSAF.csv")

# %%
# Explore data 
shark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7090 entries, 0 to 7089
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7090 non-null   object
#  1   Year            7088 non-null   float64
#  2   Type            7072 non-null   object
#  3   Country         7040 non-null   object
#  4   State           6603 non-null   object
#  5   Location        6522 non-null   object
#  6   Activity        6505 non-null   object
#  7   Name            6872 non-null   object
#  8   Sex             6512 non-null   object
#  9   Age             4093 non-null   object
#  10  Injury          7053 non-null   object
#  11  Fatal Y/N       6529 non-null   object
#  12  Time            3559 non-null   object
#  13  Species         3951 non-null   object
#  14  Source          7069 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6794 non-null   object
# ...

# %%
# Let's select what we need
shark["Fatal Y/N"].unique()
# Out:
# array(['Y', 'N', 'F', 'M', nan, 'n', 'Nq', 'UNKNOWN', '2017', 'Y x 2',
#        'y'], dtype=object)

# %%
shark.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
# There are some excess 
shark_clean = shark.drop(columns = ['Unnamed: 21','Unnamed: 22'])

# %%
shark_clean.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order'],
#       dtype='object')

# %%
# Filter out unwanted
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 shark.droplevel('F', 'M', 'nan', 'n', 'Nq', 'UNKNOWN', '2017', 'Y x 2','y', axis = 1)
#
# TypeError: NDFrame.droplevel() got multiple values for argument 'axis'

# %%
# Create train and test set
